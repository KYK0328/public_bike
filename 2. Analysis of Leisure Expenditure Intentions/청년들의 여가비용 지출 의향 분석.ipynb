# %%
# 경고메세지 제거
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib import font_manager

font_fname = 'c:/windows/fonts/malgun.ttf'
font_family = font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams['font.family'] = font_family

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
df_cost = pd.read_csv('청년들의 여가비용 지출 의향 분석 데이터.csv',engine="python")

# %%
df_cost
# Out:
#       RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0         173158         20220727               M           20대
# 1         228838         20220727               M           20대
# 2         237135         20220727               M           20대
# 3         269161         20220727               M           20대
# 4         275115         20220727               M           20대
# 5         285743         20220727               M           20대
# 6         333147         20220727               M           20대
# 7         335203         20220727               M           20대
# 8         347310         20220727               M           20대
# 9         347629         20220727               M           20대
# 10        348489         20220727               M           20대
# 11        351211         20220727               M           20대
# 12        359845         20220727               M           20대
# 13        360104         20220727               M           20대
# ...

# %%
df_cost.shape
# Out:
# (1011, 16)

# %% [markdown]
# ## 데이터 전처리

# %%
df_cost = df_cost.rename(columns = {'SEXDSTN_FLAG_CD' : '성별'})
df_cost = df_cost.rename(columns = {'AGRDE_FLAG_NM' : '연령'})
df_cost = df_cost.rename(columns = {'ANSWRR_OC_AREA_NM' : '거주지'})
df_cost = df_cost.rename(columns = {'HSHLD_INCOME_DGREE_NM' : '소득'})
df_cost = df_cost.rename(columns = {'LABOR_EMPMN_STLE_NM' : '직업'})
df_cost = df_cost.rename(columns = {'DRBGD_PRCHS_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '내구재'})
df_cost = df_cost.rename(columns = {'CLTHS_PRCHS_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '의류'})
df_cost = df_cost.rename(columns = {'BRDOT_CT_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '외식'})
df_cost = df_cost.rename(columns = {'TOUR_CT_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '여행'})
df_cost = df_cost.rename(columns = {'EDC_CT_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '교육'})
df_cost = df_cost.rename(columns = {'MDLC_CT_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '의료'})
df_cost = df_cost.rename(columns = {'CLTUR_HOBBY_CT_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '문화취미'})
df_cost = df_cost.rename(columns = {'TRNSPORT_COMMN_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '교통통신'})
df_cost = df_cost.rename(columns = {'RESIDE_CT_EXPNDTR_PRICE_VARTION_EXPECT_VALUE' : '주거'})

# %%
df_cost.head()
# Out:
#    RESPOND_ID  EXAMIN_BEGIN_DE 성별   연령    거주지              소득           직업  \
# 0      173158         20220727  M  20대  서울특별시  400만원초과700만원이하        무직/퇴직
# 1      228838         20220727  M  20대  서울특별시  200만원초과400만원이하  비정규직/일용직근로자
# 2      237135         20220727  M  20대  서울특별시          모름/무응답           학생
# 3      269161         20220727  M  20대  서울특별시          모름/무응답       정규직근로자
# 4      275115         20220727  M  20대    경기도  400만원초과700만원이하        무직/퇴직
#
#         내구재        의류        외식        여행        교육     의료      문화취미  \
# 0     비슷할 것     비슷할 것     비슷할 것     비슷할 것     비슷할 것  비슷할 것     비슷할 것
# 1     비슷할 것     비슷할 것     비슷할 것     비슷할 것     비슷할 것  비슷할 것     비슷할 것
# 2     비슷할 것  약간 늘어날 것     비슷할 것     비슷할 것  약간 줄어들 것  비슷할 것  약간 늘어날 것
# 3  약간 줄어들 것     비슷할 것     비슷할 것     비슷할 것     비슷할 것  비슷할 것     비슷할 것
# 4  약간 줄어들 것     비슷할 것  약간 줄어들 것  약간 늘어날 것     비슷할 것  비슷할 것  약간 줄어들 것
#
#        교통통신        주거
# 0     비슷할 것     비슷할 것
# 1     비슷할 것     비슷할 것
# 2     비슷할 것     비슷할 것
# ...

# %%
df = df_cost.copy()

# %%
#df = df.drop(['RESPOND_ID','EXAMIN_BEGIN_DE','소득'], axis=1)

# %%
df.head(1)
# Out:
#    RESPOND_ID  EXAMIN_BEGIN_DE 성별   연령    거주지              소득     직업    내구재  \
# 0      173158         20220727  M  20대  서울특별시  400만원초과700만원이하  무직/퇴직  비슷할 것
#
#       의류     외식     여행     교육     의료   문화취미   교통통신     주거
# 0  비슷할 것  비슷할 것  비슷할 것  비슷할 것  비슷할 것  비슷할 것  비슷할 것  비슷할 것

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 16 columns):
# RESPOND_ID         1011 non-null int64
# EXAMIN_BEGIN_DE    1011 non-null int64
# 성별                 1011 non-null object
# 연령                 1011 non-null object
# 거주지                1011 non-null object
# 소득                 1011 non-null object
# 직업                 1011 non-null object
# 내구재                1011 non-null object
# 의류                 1011 non-null object
# 외식                 1011 non-null object
# 여행                 1011 non-null object
# 교육                 1011 non-null object
# 의료                 1011 non-null object
# 문화취미               1011 non-null object
# 교통통신               1011 non-null object
# 주거                 1011 non-null object
# dtypes: int64(2), object(14)
# memory usage: 126.5+ KB

# %%
df.isna().sum()
# Out:
# RESPOND_ID         0
# EXAMIN_BEGIN_DE    0
# 성별                 0
# 연령                 0
# 거주지                0
# 소득                 0
# 직업                 0
# 내구재                0
# 의류                 0
# 외식                 0
# 여행                 0
# 교육                 0
# 의료                 0
# 문화취미               0
# 교통통신               0
# 주거                 0
# dtype: int64

# %%
df['연령'].value_counts()
# Out:
# 40대    244
# 50대    228
# 30대    211
# 20대    186
# 60대    142
# Name: 연령, dtype: int64

# %%
df['거주지'].value_counts()
# Out:
# 경기도        247
# 서울특별시      224
# 부산광역시       70
# 인천광역시       69
# 경상남도        58
# 경상북도        47
# 충청북도        45
# 대구광역시       41
# 대전광역시       40
# 광주광역시       30
# 충청남도        25
# 전라남도        23
# 울산광역시       23
# 제주특별자치도     22
# 전라북도        19
# 강원도         19
# 세종특별자치시      9
# Name: 거주지, dtype: int64

# %%
df['직업'].value_counts()
# Out:
# 정규직근로자         471
# 비정규직/일용직근로자    176
# 무직/퇴직          116
# 전업주부            96
# 사업자             90
# 학생              62
# Name: 직업, dtype: int64

# %%
df['여행'].value_counts()
# Out:
# 비슷할 것       307
# 약간 줄어들 것    250
# 많이 줄어들 것    219
# 약간 늘어날 것    196
# 많이 늘어날 것     39
# Name: 여행, dtype: int64

# %% [markdown]
# ## 데이터 int 형
# - 많이 줄 것 : 1
# - 약간 줄 것 : 2
# - 비슷할 것 : 3
# - 약간 늘 것 : 4
# - 많이 늘 것 : 5

# %%
cols = ['내구재', '의류', '외식', '여행', '교육', '의료', '문화취미', '교통통신', '주거']
# label = LabelEncoder()

# for col in cols:
#     df[col] = label.fit_transform(df[col])
df = df.replace('비슷할 것', 3)
df = df.replace('약간 줄어들 것', 2)
df = df.replace('많이 줄어들 것', 1)
df = df.replace('약간 늘어날 것', 4)
df = df.replace('많이 늘어날 것', 5)

# %%
df.head(3)
# Out:
#    RESPOND_ID  EXAMIN_BEGIN_DE 성별   연령    거주지              소득           직업  \
# 0      173158         20220727  M  20대  서울특별시  400만원초과700만원이하        무직/퇴직
# 1      228838         20220727  M  20대  서울특별시  200만원초과400만원이하  비정규직/일용직근로자
# 2      237135         20220727  M  20대  서울특별시          모름/무응답           학생
#
#    내구재  의류  외식  여행  교육  의료  문화취미  교통통신  주거
# 0    3   3   3   3   3   3     3     3   3
# 1    3   3   3   3   3   3     3     3   3
# 2    3   4   3   3   2   3     4     3   3

# %%
df['여행'].value_counts()
# Out:
# 3    307
# 2    250
# 1    219
# 4    196
# 5     39
# Name: 여행, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 16 columns):
# RESPOND_ID         1011 non-null int64
# EXAMIN_BEGIN_DE    1011 non-null int64
# 성별                 1011 non-null object
# 연령                 1011 non-null object
# 거주지                1011 non-null object
# 소득                 1011 non-null object
# 직업                 1011 non-null object
# 내구재                1011 non-null int64
# 의류                 1011 non-null int64
# 외식                 1011 non-null int64
# 여행                 1011 non-null int64
# 교육                 1011 non-null int64
# 의료                 1011 non-null int64
# 문화취미               1011 non-null int64
# 교통통신               1011 non-null int64
# 주거                 1011 non-null int64
# dtypes: int64(11), object(5)
# memory usage: 126.5+ KB

# %%
df.describe()
# Out:
#          RESPOND_ID  EXAMIN_BEGIN_DE          내구재           의류           외식  \
# count  1.011000e+03           1011.0  1011.000000  1011.000000  1011.000000
# mean   4.926363e+07       20220727.0     2.421365     2.591494     2.661721
# std    1.413593e+07              0.0     1.081115     0.975079     1.043750
# min    1.731580e+05       20220727.0     1.000000     1.000000     1.000000
# 25%    5.333084e+07       20220727.0     2.000000     2.000000     2.000000
# 50%    5.334680e+07       20220727.0     2.000000     3.000000     3.000000
# 75%    5.336125e+07       20220727.0     3.000000     3.000000     3.000000
# max    5.337750e+07       20220727.0     5.000000     5.000000     5.000000
#
#                 여행          교육           의료         문화취미         교통통신  \
# count  1011.000000  1011.00000  1011.000000  1011.000000  1011.000000
# mean      2.590504     2.76360     2.981207     2.573689     2.978239
# std       1.138206     0.98126     0.844694     1.040402     0.845209
# ...

# %%
# 연령대 비율 확인
df['연령'].value_counts(normalize = True)*100
# Out:
# 40대    24.134520
# 50대    22.551929
# 30대    20.870425
# 20대    18.397626
# 60대    14.045500
# Name: 연령, dtype: float64

# %%
sns.countplot(data = df, x = '연령', palette='Blues_r')

# %%
# def show_plot(cols, fsize=(10, 6), order = None):
#     if not order:
#         order = df[cols].value_counts().index
        
#     plt.figure(figsize = fsize)
#     sns.countplot(data = df, y=cols, palette = 'Blues_r', order = order)
    
# show_plot('문화취미', fsize=(6, 4))

# %% [markdown]
# ## 나이대 별 문화취미에 대한 소비 의향 분석

# %%
# age_cul = pd.crosstab(df['연령'], df['문화취미'])
# age_cul[[1,2,3,4,5]].plot.barh(figsize =(10,6))
age_cul = pd.crosstab(df['연령'], df['문화취미'])
age_cul[[4,5]].plot.barh(figsize =(10,6))

# %% [markdown]
# ### 20-30 대 늘릴생각 있음
# ## 나이대 별 교통통신에 대한 소비 의향 분석

# %%
age_trans = pd.crosstab(df['연령'], df['교통통신'])
age_trans[[4,5]].plot.barh(figsize =(10,6))

# %% [markdown]
# ### 20-30 대 늘릴생각 있음
#
# ## 나이대 별 여행에 대한 소비 의향 분석

# %%
age_travel = pd.crosstab(df['연령'], df['여행'])
age_travel[[1,2,3,4,5]].plot.barh(figsize =(10,6))

# %%
age_home = pd.crosstab(df['연령'], df['주거'])
age_home[[1,2,3,4,5]].plot.barh(figsize =(10,6))

# %%
sns.barplot(data=df, y="교통통신", x="연령")

# %%
df_old = df.groupby(['연령'])
df_old.get_group('20대')['문화취미'].value_counts(ascending = False)
# Out:
# 3    74
# 4    54
# 2    29
# 1    18
# 5    11
# Name: 문화취미, dtype: int64

# %%
df_cul_p = pd.DataFrame(df['문화취미'].groupby(df['연령']).value_counts())
df_cul_p.columns = ['cnt']
df_cul_p = df_cul_p.reset_index()
df_cul_p = pd.pivot_table(df_cul_p, index = '연령', columns = '문화취미', values = 'cnt')
df_cul_p = df_cul_p.reset_index()

# %%
df_cul_p
# Out:
# 문화취미   연령     1     2      3     4     5
# 0     20대  18.0  29.0   74.0  54.0  11.0
# 1     30대  31.0  51.0   86.0  33.0  10.0
# 2     40대  46.0  72.0  100.0  22.0   4.0
# 3     50대  64.0  63.0   73.0  25.0   3.0
# 4     60대  31.0  41.0   55.0  15.0   NaN

# %%
# 60대 5에서 NaN이 나온 이유
sum((df['연령']=='60대') & (df['문화취미']==5))
# Out:
# 0

# %%
df_trans_p = pd.DataFrame(df['교통통신'].groupby(df['연령']).value_counts())
df_trans_p.columns = ['cnt']
df_trans_p = df_trans_p.reset_index()
df_trans_p = pd.pivot_table(df_trans_p, index = '연령', columns = '교통통신', values = 'cnt')
df_trans_p= df_trans_p.reset_index()

# %%
df_trans_p
# Out:
# 교통통신   연령   1   2    3   4   5
# 0     20대   9  15   98  51  13
# 1     30대   7  29  116  51   8
# 2     40대  13  40  152  31   8
# 3     50대  24  38  137  24   5
# 4     60대  10  26   80  25   1
